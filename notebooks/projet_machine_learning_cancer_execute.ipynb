# %% [markdown]
# # Projet Machine Learning - Classification de tumeurs mammaires
#
# Ce notebook execute le projet complet : probleme, donnees, EDA, preparation, modelisation, evaluation, analyse et conclusion. Le rapport final detaille est genere dans `reports/rapport_projet_machine_learning.md`.

# %% [markdown]
# ## 1. Probleme
#
# L'objectif est de classifier des tumeurs mammaires en `benign` ou `malignant` a partir de mesures numeriques. La priorite metier est de maximiser le rappel de la classe maligne afin de limiter les faux negatifs.

# %% [markdown]
# ## 2. Donnees
#
# Le jeu de donnees utilise est Breast Cancer Wisconsin Diagnostic, disponible via `sklearn.datasets.load_breast_cancer` et provenant du UCI Machine Learning Repository.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.projet_ml_cancer import load_data

df, X, y, feature_names = load_data()
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst perimeter  worst area  worst smoothness  \
# 0                 0.07871  ...           184.60      2019.0            0.1622
# 1                 0.05667  ...           158.80      1956.0            0.1238
# 2                 0.05999  ...           152.50      1709.0            0.1444
# 3                 0.09744  ...            98.87       567.7            0.2098
# 4                 0.05883  ...           152.20      1575.0            0.1374
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    worst fractal dimension  diagnosis  target_malignant
# 0                  0.11890  malignant                 1
# 1                  0.08902  malignant                 1
# 2                  0.08758  malignant                 1
# 3                  0.17300  malignant                 1
# 4                  0.07678  malignant                 1
#
# [5 rows x 32 columns]

# %%
df.shape, df['diagnosis'].value_counts()
# Out:
# ((569, 32),
#  diagnosis
#  benign       357
#  malignant    212
#  Name: count, dtype: int64)

# %% [markdown]
# ## 3. Analyse exploratoire des donnees
#
# Les graphiques EDA sont generes automatiquement par le script principal et sauvegardes dans `outputs/figures/`.

# %% [markdown]
# ## 4. Preparation
#
# La preparation respecte un split train/test stratifie. Les imputations, standardisations et reductions de dimension sont integrees dans des pipelines afin d'eviter les fuites de donnees.

# %% [markdown]
# ## 5. Modelisation
#
# Les modeles compares incluent regression logistique, KNN, SVM RBF, Random Forest, Gradient Boosting, PCA + regression logistique et Random Forest optimisee.

# %% [markdown]
# ## 6. Evaluation
#
# Les metriques principales sont le rappel de la classe maligne, la precision, la specificite, le F1-score, l'AUC ROC et l'accuracy.

# %%
from src.projet_ml_cancer import main

summary = main()
summary
# Out:
# {
#   "best_model": "PCA + regression logistique",
#   "best_test_metrics": {
#     "model": "PCA + regression logistique",
#     "accuracy": 0.9736842105263158,
#     "precision_malignant": 0.9534883720930233,
#     "recall_malignant": 0.9761904761904762,
#     "specificity_benign": 0.9722222222222222,
#     "f1_malignant": 0.9647058823529412,
#     "roc_auc": 0.9966931216931216
#   },
#   "report": "reports/rapport_projet_machine_learning.md",
#   "model": "models/best_model.joblib"
# }
# {'best_model': 'PCA + regression logistique',
#  'best_test_metrics': {'model': 'PCA + regression logistique',
#   'accuracy': 0.9736842105263158,
#   'precision_malignant': 0.9534883720930233,
#   'recall_malignant': 0.9761904761904762,
#   'specificity_benign': 0.9722222222222222,
#   'f1_malignant': 0.9647058823529412,
#   'roc_auc': 0.9966931216931216},
#  'report': 'reports/rapport_projet_machine_learning.md',
#  'model': 'models/best_model.joblib'}

# %%
import pandas as pd

pd.read_csv(ROOT / 'outputs/tables/test_results.csv')
# Out:
#                          model  accuracy  precision_malignant  \
# 0  PCA + regression logistique  0.973684             0.953488
# 1                      SVM RBF  0.982456             0.976190
# 2        Regression logistique  0.973684             0.975610
# 3                Random Forest  0.973684             1.000000
# 4       Random Forest optimise  0.973684             1.000000
# 5            Gradient Boosting  0.964912             1.000000
# 6       K plus proches voisins  0.956140             0.974359
#
#    recall_malignant  specificity_benign  f1_malignant   roc_auc
# 0          0.976190            0.972222      0.964706  0.996693
# 1          0.976190            0.986111      0.976190  0.995370
# 2          0.952381            0.986111      0.963855  0.995370
# 3          0.928571            1.000000      0.962963  0.997189
# 4          0.928571            1.000000      0.962963  0.997024
# 5          0.904762            1.000000      0.950000  0.994709
# 6          0.904762            0.986111      0.938272  0.982474

# %% [markdown]
# ## 7. Analyse
#
# L'analyse detaillee, les matrices de confusion, les courbes ROC, les importances de variables, la PCA et KMeans sont disponibles dans le rapport genere.

# %% [markdown]
# ## 8. Conclusion
#
# Le modele retenu est celui qui maximise le rappel de la classe maligne, puis l'AUC ROC et le F1-score. Voir `reports/rapport_projet_machine_learning.md` pour les recommandations et limites.
